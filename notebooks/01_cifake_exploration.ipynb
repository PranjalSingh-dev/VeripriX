# %% [markdown]
# # 01. CIFAKE & DiffusionDB Dataset Exploration
# This notebook explores class balance, image dimensions, noise variance, and frequency spectra for real vs AI-generated images.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

print('Dataset exploration ready.')
