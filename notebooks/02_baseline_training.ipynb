# %% [markdown]
# # 02. Baseline AI Image Detection Classifier Training
# Trains a ResNet50 / EfficientNet transfer learning binary classifier to distinguish real photos from AI-generated images.

# %%
import torch
import torchvision.models as models
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Training environment initialized on device: {device}')
